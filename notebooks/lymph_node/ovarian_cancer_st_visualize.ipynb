# %%
import scanpy as sc
adata=sc.read("II21472.h5ad")
sc.pl.spatial(adata, color=[None, 'EPCAM'], size=1.5)

# %%
sc.pp.neighbors(adata)
sc.tl.leiden(adata)
# Out:
# WARNING: You’re trying to run this on 36601 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
print(adata.obs.head())
# Out:
#                     in_tissue  array_row  array_col leiden
# AAACACCAATAACTGC-1          1         59         19      0
# AAACTGCTGGCTCCAA-1          1         45         67      2
# AAACTTGCAAACGTAT-1          1         45         19      6
# AAAGGCTCTCGCGCCG-1          1         55         55      3
# AAATACCTATAAGCAT-1          1         47         69      4

# %%
sc.pl.spatial(adata, color='leiden', size=1.5)
