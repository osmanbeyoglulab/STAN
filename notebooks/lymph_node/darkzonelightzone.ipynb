# %%
import numpy as np
import scanpy as sc
import pandas as pd
import stan
# Out:
# OMP: Info #273: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
adata=sc.read_h5ad("/Users/student/Library/CloudStorage/OneDrive-UniversityofPittsburgh/code/stan/data/lymph_node/visium_lymph_node.h5ad")

# %%
sc.pl.spatial(adata, color=['germinal_center','CXCR4', 'CD83'])

# %%
# !pwd
# Out:
# /Users/student/Library/CloudStorage/OneDrive-UniversityofPittsburgh/code/stan/notebooks/lymph_node

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4033 × 21261
#     obs: 'in_tissue', 'array_row', 'array_col', 'germinal_center'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells'
#     uns: 'spatial'
#     obsm: 'celltype', 'celltype_raw', 'spatial'

# %%
adata.obsm['spatial']
# Out:
# array([[8346, 6982],
#        [4270, 1363],
#        [2635, 8074],
#        ...,
#        [3181, 6396],
#        [4153, 9747],
#        [4822, 1840]])
